# %%
import pickle
def save2picke(data, file_name):
    with open('./pickle/'+file_name+'.pickle', 'wb') as f:
        pickle.dump(data, f)
        
def read4picke(file_name):
    with open('./pickle/'+file_name+'.pickle', 'rb') as f:
        return pickle.load(f)
    assert 'there is no such file' == 0
        
# kk = read4picke('score for GD_primary')
# print(kk)
def saveMsgAsPickle(FileName, iteration_l, norm_del_f_l, score_l, time_l):
    save2picke(score_l, FileName + 'score_l')
    save2picke(time_l, FileName + 'time_l')
    save2picke(iteration_l, FileName + 'iteration_l')
    save2picke(norm_del_f_l, FileName + 'norm_del_f_l')
    
def getMsgFromPickle(FileName):
    score_l = read4picke(FileName + 'score_l')
    time_l = read4picke(FileName + 'time_l')
    iteration_l = read4picke(FileName + 'iteration_l')
    norm_del_f_l = read4picke(FileName + 'norm_del_f_l')
    return iteration_l, norm_del_f_l, score_l, time_l

# %%
iteration_l, norm_del_f_l, score_l, time_l = getMsgFromPickle('stochastic-general-k16-')

# %%
import matplotlib.pyplot as plt
time_l_new = [sum(time_l[:i]) for i in range(len(time_l))]
plt.plot(time_l_new, score_l, marker='^', linestyle='-',label=r'$f\ (x^{k})$'+' vs time')
plt.ylabel(r'$f\ (x^{k})$')
plt.xlabel(r'$time\ (s)$')
plt.legend()
plt.title(r'$f\ (x^{k})$ vs time with general gradient descent')
plt.savefig("./gen-img/plot/$f\ (x^{k})$ vs time with general gradient descent.png", dpi=300)
plt.show()

# %%
def plotTime(time_l, score_l, marker, label):
    time_l_new = [sum(time_l[:i]) for i in range(len(time_l))]
    plt.plot(time_l_new, score_l, marker = marker,label = label, linestyle='-')
    
# time_l_new = [sum(time_l[:i]) for i in range(len(time_l))]
# time_l_new_gd = [sum(time_l[:i]) for i in range(len(time_l))]

iteration_l, norm_del_f_l, score_l, time_l = getMsgFromPickle('stochastic-general-k16-')
label=r'$f\ (x^{k})$'+' vs time with Stochastic method (s=16)'
marker = '^'
plotTime(time_l, score_l, marker, label)

iteration_l, norm_del_f_l, score_l, time_l = getMsgFromPickle('stochastic-general-k8-')
label=r'$f\ (x^{k})$'+' vs time with Stochastic method (s=8)'
marker = '>'
plotTime(time_l, score_l, marker, label)

iteration_l, norm_del_f_l, score_l, time_l = getMsgFromPickle('stochastic-general-k4-')
label=r'$f\ (x^{k})$'+' vs time with Stochastic method (s=4)'
marker = '<'
plotTime(time_l, score_l, marker, label)

iteration_l, norm_del_f_l, score_l, time_l = getMsgFromPickle('stochastic-general-k2-')
label=r'$f\ (x^{k})$'+' vs time with Stochastic method (s=2)'
marker = '<'
plotTime(time_l, score_l, marker, label)

iteration_l, norm_del_f_l, score_l, time_l = getMsgFromPickle('stochastic-large-size-\
problem-lambda-0.9-k2-')
label=r'$f\ (x^{k})$'+' vs time with weighted Stochastic method (s=2)'
marker = '<'
plotTime(time_l, score_l, marker, label)

# iteration_l, norm_del_f_l, score_l, time_l = getMsgFromPickle('GD-Nesterov-')
# label=r'$f\ (x^{k})$'+' vs time accelerated by Nestrov method'
# marker = '.'
# plotTime(time_l, score_l, marker, label)

# iteration_l, norm_del_f_l, score_l, time_l = getMsgFromPickle('GD-general-')
# label=r'$f\ (x^{k})$'+' vs time with general gradient discent'
# marker = 'x'
# plotTime(time_l, score_l, marker, label)

plt.ylabel(r'$f\ (x^{k})$')
plt.xlabel(r'$time\ (s)$')
plt.legend()
# plt.yscale('log') 
plt.title(r'$f\ (x^{k})$'+' vs time ')
plt.savefig("./gen-img/plot/$f\ (x^{k})$ vs time $k$-stochastic.png", dpi=300)
plt.show()

# %%
def plotItr(iteration_l, score_l, marker, label):
    plt.plot(iteration_l, score_l, marker = marker,label = label, linestyle='-')
    
# time_l_new = [sum(time_l[:i]) for i in range(len(time_l))]
# time_l_new_gd = [sum(time_l[:i]) for i in range(len(time_l))]

iteration_l, norm_del_f_l, score_l, time_l = getMsgFromPickle('stochastic-general-k16-')
label=r'$f\ (x^{k})$ vs iteration $k$ with Stochastic method (s=16)'
marker = '^'
plotItr(iteration_l, score_l, marker, label)

iteration_l, norm_del_f_l, score_l, time_l = getMsgFromPickle('stochastic-general-k8-')
label=r'$f\ (x^{k})$ vs iteration $k$ with Stochastic method (s=8)'
marker = '>'
plotItr(iteration_l, score_l, marker, label)

iteration_l, norm_del_f_l, score_l, time_l = getMsgFromPickle('stochastic-general-k4-')
label=r'$f\ (x^{k})$ vs iteration $k$ with Stochastic method (s=4)'
marker = '<'
plotItr(iteration_l, score_l, marker, label)

iteration_l, norm_del_f_l, score_l, time_l = getMsgFromPickle('stochastic-general-k2-')
label=r'$f\ (x^{k})$ vs iteration $k$ with Stochastic method (s=2)'
marker = '<'
plotItr(iteration_l, score_l, marker, label)

iteration_l, norm_del_f_l, score_l, time_l = getMsgFromPickle('stochastic-large-size-\
problem-lambda-0.9-k2-')
label=r'$f\ (x^{k})$'+' vs time with weighted Stochastic method (s=2)'
marker = '<'
plotItr(iteration_l, score_l, marker, label)

# iteration_l, norm_del_f_l, score_l, time_l = getMsgFromPickle('GD-Nesterov-')
# label=r'$f\ (x^{k})$ vs iteration $k$  accelerated by Nestrov method'
# marker = '.'
# plotItr(iteration_l, score_l, marker, label)

# iteration_l, norm_del_f_l, score_l, time_l = getMsgFromPickle('GD-general-')
# label=r'$f\ (x^{k})$ vs iteration $k$ with general gradient discent'
# marker = 'x'
# plotItr(iteration_l, score_l, marker, label)


# plt.plot(iteration_l, score_l, marker='^', linestyle='-',label=r'$f\ (x^{k})$'+' vs '+'iteration '+r'$k$ accelerated by Nestrov method'  )
# plt.plot(iteration_l_gd, score_l_gd, marker='.', linestyle='-',label=r'$f\ (x^{k})$'+' vs '+'iteration '+r'$k$ for general GD')
plt.ylabel(r'$f\ (x^{k})$')
plt.xlabel('iteration '+r'$k$')
plt.legend()
plt.title(r'$f\ (x^{k})$'+' vs '+'iteration '+r'$k$''')
plt.savefig("./gen-img/plot/$f\ (x^{k})$ vs iteration $k$-stochastic.png", dpi=300)
plt.show()
